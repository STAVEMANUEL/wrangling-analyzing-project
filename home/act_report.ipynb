# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# #### Data analysis is more than just presenting numbers, it's more about finding creative ways to tell the story.
# WeRateDogs is one of the most famous memes of 2016 you may have heard of. I will tell you a little about it here as well as show you some interesting analysis of WeRateDog tweets.
# The WeRateDogs twitter archive contains basic tweet data for all 5000+ of their tweets, so it is very important to work with 'clean' data (as much as possible), most of the data comes dirty and that is way it is so important to clean the data in order to get the real results.
#
# With a humorous comment about the dog, WeRateDogs rates people's dogs on Twitter.
# WeRateDogs is a twitter account that rates dogs with hummor.
# Using Python and its libraries i gathered, assessed and clean the data to esblished and analyzie the following insights:
# - what is the most popular breed.
# - what is the most popular dog names.
# - Comparing retweets and favorites counts over time.

# %% [markdown]
# WeRateDogs Twitter data was retrieved from Twitter's API using Tweepy, a Python library. Among the data will be the number of retweets and favorites. As part of this project, I combined those two pieces of data with additional information provided by Udacity's Data Analyst course.

# %% [markdown]
# ###  The most popular dog names are Copper, charlie and oliver

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('names.png')
imgplot = plt.imshow(img)
plt. show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### After cleaning the information through visualization I found out what the most popular touch was:
# ## Golden Retriever!

# %%
img = mpimg.imread('breeds.png')
imgplot = plt.imshow(img)
plt. show()

# %% [markdown]
# ##### By Comparing retweets and favorites counts over time we can see that there is a positive correlation between favorite counts and retweet counts.

# %%
img = mpimg.imread('retweetsvsfavorites.png')
imgplot = plt.imshow(img)
plt.show()
